# %% [markdown]
# # Data Exploration

# %%
import pandas as pd

from lib import plots

# %%
df_matches = pd.read_pickle("data/matches.pkl")
df_matches = df_matches[df_matches["season"] < 2025]  # Use only past seasons

# %%
plots.scoreline_distribution(df_matches, top_k=16)

# %% [markdown]
# **Key insights**:
# - 1:1 is by far the most common scoreline
# - most common scorelines are low scoring (0:0, 1:0, 0:1, 2:1, 1:2)
# - home advantage is clearly visible in the data

# %%
plots.host_advantage(df_matches)

# %% [markdown]
# **Key insight**: Home team has clear advantage

# %%
plots.goals_distribution(df_matches)

# %% [markdown]
# **Key insight**: Scored goals roughly follow a Poisson distribution.
